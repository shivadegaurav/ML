# %%
pip install opencv-python
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.0 MB 8.6 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/39.0 MB 7.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/39.0 MB 8.9 MB/s eta 0:00:04
#    -------- ------------------------------- 7.9/39.0 MB 10.7 MB/s eta 0:00:03
#    ------------ --------------------------- 12.1/39.0 MB 12.8 MB/s eta 0:00:03
#    ------------------- -------------------- 18.6/39.0 MB 16.1 MB/s eta 0:00:02
#    ------------------------- -------------- 24.9/39.0 MB 18.3 MB/s eta 0:00:01
#    ------------------------------- -------- 30.9/39.0 MB 19.7 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.0 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 20.6 MB/s eta 0:00:00
# ...

# %%
import cv2
import numpy as np

# %%
img = cv2.imread("img.jpg")
cv2.imshow("window",img)
cv2.waitKey(0)
# Out:
# -1
