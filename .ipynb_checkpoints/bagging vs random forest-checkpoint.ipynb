# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier , RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5, n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.208628  0.499243  1.426811 -2.478787 -0.385936       0
# 1 -0.737617 -0.650287  0.499354 -0.656241  0.902462       0
# 2 -0.846577 -0.058366 -2.491605 -1.770101 -1.013056       0
# 3  1.202421 -1.516611  1.433701 -0.033032 -5.470632       0
# 4 -0.723444 -0.529318 -1.895018  1.308730  0.103006       1

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# Features and target
X = df.iloc[:, :5]
y = df.iloc[:, -1]

# Define model
rf = RandomForestClassifier(max_features=2, random_state=42)

# Perform 5-fold cross validation
scores = cross_val_score(rf, X, y, cv=5, scoring='accuracy')

print("Cross-validation scores:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Cross-validation scores: [0.8  1.   0.8  1.   0.85]
# Mean accuracy: 0.89

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(rf, X, y, cv=cv, scoring='accuracy')

print("Stratified CV scores:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Stratified CV scores: [0.9  0.9  0.85 0.9  0.95]
# Mean accuracy: 0.9

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(bag, X, y, cv=5, scoring='accuracy')
print("Cross-validation scores:", scores)
print("Mean CV Accuracy:", scores.mean())
# Out:
# Cross-validation scores: [0.9  0.95 0.7  0.95 0.95]
# Mean CV Accuracy: 0.89

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = cross_val_score(bag, X, y, cv=cv, scoring='accuracy')

print("Stratified K-Fold scores:", scores)
print("Mean accuracy:", scores.mean())
# Out:
# Stratified K-Fold scores: [0.8  0.75 0.95 0.95 0.9 ]
# Mean accuracy: 0.8700000000000001
