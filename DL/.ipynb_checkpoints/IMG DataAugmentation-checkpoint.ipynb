# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# ImportError: cannot import name 'img_to_array' from 'keras.preprocessing.image' (F:\Anaconda\envs\tf_final\lib\site-packages\keras\preprocessing\image.py)
